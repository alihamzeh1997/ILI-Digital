# %% [markdown]
# # Complete RAG System with Company-Aware Retrieval
#
# ## Overview
# This notebook implements a Retrieval-Augmented Generation (RAG) system that:
# 1. Loads company data and creates a vector database
# 2. Detects company names in user queries
# 3. Expands queries in up to 5 different perspectives
# 4. Retrieves documents with metadata filtering (company-aware)
# 5. Generates answers strictly from retrieved context

# %% [markdown]
# ## 1. Environment Setup

# %%
# !pip install -q langchain langchain-community langchain-openai chromadb openai pandas

# %%
import pandas as pd
import os
from typing import List
from pydantic import BaseModel, Field
from langchain_core.documents import Document
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

print("✓ All imports successful")
# Out:
# ✓ All imports successful

# %% [markdown]
# ## 2. Configuration

# %% [markdown]
# In the following cell, we will configure variables such as the OpenAI and OpenRouter API keys for the embedding model and the LLM. The `K_DOCUMENTS = 5` variable determines the number of documents to retrieve for each query. For this task we will use `Deepseek` for the LLM.

# %%
# IMPORTANT: Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = "API_KEY"
Open_Router_API_Key = "API_KEY"
# Configuration
K_DOCUMENTS = 5
# LLM_MODEL = "nex-agi/deepseek-v3.1-nex-n1:free" # From OpenRouter
# LLM_MODEL = "amazon/nova-2-lite-v1:free"
LLM_MODEL = 'gpt-5-nano-2025-08-07'
CHROMA_DIR = "/Users/alihamzeh/Downloads/ILI-Digital/chroma_db"

# %% [markdown]
# ## 3. Load Data

# %% [markdown]
# The vector database will be constructed utilizing the refined and enriched dataset. To make the vector database more comprehensive, I enriched the descriptions by adding additional structured information using `DeepSeek v3.1`, including Primary Industry, Related Industries, Products and Services, and Expanded Keywords. The purpose of this step was to increase contextual depth by expanding key terms. For example, terms such as Wind Power were expanded to include Energy, Renewable Energy, Green Energy, and similar concepts, thereby improving the likelihood of more accurate and relevant retrieval.

# %%
# Load company dataset
df = pd.read_csv('/Users/alihamzeh/Downloads/ILI-Digital/Data Manipulation/companies_enriched_deepseek.csv')
print(f"✓ Loaded {len(df)} companies")
df.head()
# Out:
# ✓ Loaded 105 companies
#              companyName                               original_description  \
# 0              Traton SE  Traton SE manufactures commercial vehicles wor...
# 1           2G Energy AG  2G Energy AG, together with its subsidiaries, ...
# 2    MTU Aero Engines AG  MTU Aero Engines AG, together with its subsidi...
# 3  Deutsche Lufthansa AG  Deutsche Lufthansa AG operates as an aviation ...
# 4      Siemens Energy AG  Siemens Energy AG operates as an energy techno...
#
#                    primary_industry  \
# 0  commercial vehicle manufacturing
# 1                    Energy Systems
# 2             Aerospace and Defense
# 3                          Aviation
# 4                 Energy Technology
#
#                                   related_industries  \
# 0         ["automotive", "transportation equipment"]
# 1  ["Power Generation", "Combined Heat and Power"...
# 2  ["Aviation", "Aerospace Manufacturing", "Defen...
# 3        ["Airlines", "Aerospace", "Transportation"]
# 4  ["Power Generation", "Renewable Energy", "Oil ...
#
#                                    products_services  \
# 0  ["trucks", "buses", "vans", "construction vehi...
# 1  ["Combined Heat and Power (CHP) Systems", "g-b...
# 2  ["Commercial aircraft engines", "Military airc...
# 3  ["Passenger services", "Cargo transport servic...
# 4  ["gas turbines", "steam turbines", "generators...
#
#                                    expanded_keywords  \
# 0  ["MAN", "Scania", "Navistar", "Volkswagen Cami...
# 1  ["CHP Systems", "Cogeneration", "Decentralized...
# 2  ["Aero engines", "Jet engines", "Gas turbines"...
# 3  ["Lufthansa", "German airline", "International...
# 4  ["energy technology", "power generation", "gas...
#
#                                      searchable_text
# 0  Company: Traton SE\nDescription: Traton SE man...
# 1  Company: 2G Energy AG\nDescription: 2G Energy ...
# 2  Company: MTU Aero Engines AG\nDescription: MTU...
# 3  Company: Deutsche Lufthansa AG\nDescription: D...
# 4  Company: Siemens Energy AG\nDescription: Sieme...

# %% [markdown]
# ## 4. Create Vector Database

# %% [markdown]
# To make our RAG system work better, we will use the `searchable_text` column. This column has extra details and keywords added by an LLM, and it will be the main content for our vector database. We will also use `companyName` to filter search results if the questions mention specific companies. The `OpenAI embedding model` is used to create this vector database, and we'll keep using this same model for all future steps to ensure consistency. For chunking, each row will be treated as a separate chunk, as the length of each row is sufficiently short to be considered an appropriate split. Additionally, each row contains enough contextual information related to its corresponding company.

# %%
df["description_word_count"] = (
    df["searchable_text"]
    .astype(str)
    .str.split()
    .str.len()
)
df.describe()
# Out:
#        description_word_count
# count              105.000000
# mean               223.761905
# std                 69.790693
# min                 72.000000
# 25%                176.000000
# 50%                219.000000
# 75%                271.000000
# max                384.000000

# %%
# Prepare documents with metadata
documents = [
    Document(
        page_content=row['searchable_text'],
        metadata={'company_name': row['companyName']}
    )
    for _, row in df.iterrows()
]

# Create vector store
embeddings = OpenAIEmbeddings()
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embeddings,
    persist_directory=CHROMA_DIR
)

print(f"✓ Vector database created with {len(documents)} documents")
# Out:
# ✓ Vector database created with 105 documents

# %% [markdown]
# ## 5. Company Detection System

# %% [markdown]
# In this section, to filter companies mentioned in the user query, we first use an LLM to analyze the query and identify any referenced companies. The model extracts the correct spelling of each company based on a provided list, after which the output is parsed to construct a metadata-based search query. This approach enables precise filtering of the vector database, allowing us to retrieve the exact companies prior to performing similarity-based searches.

# %%
VALID_COMPANIES = df['companyName'].unique().tolist()

class CompanyExtraction(BaseModel):
    company_names: List[str] = Field(
        default_factory=list,
        description=f"Company names from this list: {VALID_COMPANIES}. Empty if none found."
    )

# llm = ChatOpenAI(
#     model=LLM_MODEL, # For changing the model refer to the Config section
#     temperature=0,
#     openai_api_base="https://openrouter.ai/api/v1",
#     openai_api_key= Open_Router_API_Key,
# )


llm = ChatOpenAI(
    model=LLM_MODEL, # For changing the model refer to the Config section
    temperature=0,
)

company_parser = JsonOutputParser(pydantic_object=CompanyExtraction)

company_extraction_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "Your task is to extract company names explicitly mentioned in the user query.\n\n"
        "Rules:\n"
        "- Do NOT infer, guess, or predict company names.\n"
        "- Only extract a company if it is explicitly mentioned in the query.\n"
        "- Only return companies that exist in the following list: {company_list}.\n"
        "- If the query mentions a partial, lowercase, or variant form of a company name "
        "(e.g., 'traton'), map it to the exact company name as written in the company list "
        "(e.g., 'Traton SE').\n"
        "- If no company from the list is explicitly mentioned, return an empty list.\n\n"
        "{format_instructions}"
    ),
    ("human", "{query}")
]).partial(
    format_instructions=company_parser.get_format_instructions(),
    company_list=str(VALID_COMPANIES)
)

company_extraction_chain = company_extraction_prompt | llm | company_parser
print("✓ Company detection system ready")
# Out:
# ✓ Company detection system ready

# %% [markdown]
# ## 6. Query Expansion System

# %% [markdown]
# To further improve the precision and comprehensiveness of the RAG system, I implemented a query expansion mechanism that generates up to five alternative queries from the original input. This approach ensures broader coverage of the query’s different aspects, enabling more focused and effective retrieval.

# %%
class ExpandedQueries(BaseModel):
    queries: List[str] = Field(
        ...,
        description="3 expanded queries rephrasing the original from different perspectives"
    )

query_expansion_parser = JsonOutputParser(pydantic_object=ExpandedQueries)

query_expansion_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "Your task is to expand the original user query into up to five distinct, non-overlapping "
        "sub-queries by decomposing it into smaller, well-defined components.\n\n"
        "Each generated sub-query must focus on a DIFFERENT aspect, condition, or constraint "
        "explicitly implied by the original query. For example, if the original query is "
        "`companies in renewable energy and financial services`, you must generate at least one "
        "sub-query targeting the renewable energy aspect and one targeting the financial services "
        "aspect.\n\n"
        "Do NOT generate multiple sub-queries with the same meaning.\n\n"
        "The generated sub-queries will be used for semantic search. Therefore:\n"
        "- Make each sub-query long, detailed, and information-dense.\n"
        "- Preserve the original intent exactly.\n"
        "- Include all relevant context from the original query in each sub-query where applicable.\n"
        "- Prefer explicit, descriptive phrasing over short or vague questions.\n\n"
        "When the query contains industrial, sectoral, or domain-specific terms, expand them using "
        "closely related synonyms or equivalent industry terminology "
        "(e.g., 'wind power' → 'wind energy', 'renewable energy', 'green energy', 'energy sector').\n\n"
        "RULES:\n"
        "1. Generate between 1 and 5 sub-queries (maximum of 5).\n"
        "2. Do NOT introduce new facts, entities, industries, or constraints that are not implied "
        "by the original query.\n"
        "3. Each sub-query must represent a unique aspect or constraint of the original query; "
        "avoid semantic overlap.\n"
        "4. Paraphrasing and decomposition are allowed only within the scope of the original intent.\n"
        "5. If multiple conditions are implied (e.g., sector A AND sector B), separate them into "
        "individual sub-queries.\n"
        "6. If company names are explicitly mentioned, keep their spelling unchanged.\n"
        "7. Avoid speculative, hypothetical, or predictive wording.\n\n"
        "{format_instructions}"
    ),
    ("human", "Original query: {query}")
]).partial(
    format_instructions=query_expansion_parser.get_format_instructions()
)


query_expansion_chain = query_expansion_prompt | llm | query_expansion_parser
print("✓ Query expansion system ready")
# Out:
# ✓ Query expansion system ready

# %% [markdown]
# ## 7. Contextual Retriever

# %% [markdown]
# In the following section, we integrate all the components developed so far to retrieve the documents relevant to the user query and prepare them for input to the model.

# %%
def contextual_retriever(queries: List[str], k: int = K_DOCUMENTS) -> List[Document]:
    retrieved_docs = []
    seen_contents = set()

    for query in queries:
        extraction = company_extraction_chain.invoke({"query": query})
        companies = extraction.get('company_names', [])

        if companies:
            print(f"🔍 '{query[:50]}...' → Companies: {companies}")
            for company in companies:
                retriever = vectorstore.as_retriever(
                    search_kwargs={"filter": {"company_name": company}, "k": k}
                )
                docs = retriever.invoke(query)
                for doc in docs:
                    if doc.page_content not in seen_contents:
                        seen_contents.add(doc.page_content)
                        retrieved_docs.append(doc)
        else:
            print(f"🔍 '{query[:50]}...' → Broad search")
            retriever = vectorstore.as_retriever(search_kwargs={"k": k})
            docs = retriever.invoke(query)
            for doc in docs:
                if doc.page_content not in seen_contents:
                    seen_contents.add(doc.page_content)
                    retrieved_docs.append(doc)

    print(f"✓ Retrieved {len(retrieved_docs)} unique documents\n")
    return retrieved_docs

# %% [markdown]
# ## 8. Answer Generation

# %% [markdown]
# Here, we define the model input prompt by specifying the system message, the retrieved context, and the original user query.

# %%
answer_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a precise QA assistant. CRITICAL:\n"
        "1. Answer ONLY from the provided context\n"
        "2. No external knowledge\n"
        "3. Say 'Cannot answer' if context insufficient\n"
        "4. Keep the answer short and concise\n"
        "5. Be specific and cite details\n\n"
        "Context:\n{context}"
    ),
    ("human", "{question}")
])

# %% [markdown]
# ## 9. Complete RAG Pipeline

# %%
def rag_pipeline(user_query: str, verbose: bool = True) -> str:
    if verbose:
        print("="*80)
        print(f"Query: {user_query}\n")

    # Expand query
    expansion = query_expansion_chain.invoke({"query": user_query})
    expanded_queries = expansion['queries']

    if verbose:
        print("Expanded queries:")
        for i, q in enumerate(expanded_queries, 1):
            print(f"  {i}. {q}")
        print()

    # Retrieve documents
    all_queries = [user_query] + expanded_queries
    docs = contextual_retriever(all_queries)

    # Format context
    context = "\n\n---\n\n".join(d.page_content for d in docs)

    if verbose:
        companies = set(d.metadata['company_name'] for d in docs)
        print(f"Context: {len(context)} chars from companies: {companies}\n")

    # Generate answer
    answer_chain = answer_prompt | llm | StrOutputParser()
    answer = answer_chain.invoke({"context": context, "question": user_query})

    if verbose:
        print("="*80)
        print(f"context: {context}\n")
        print(f"question: {user_query}\n")
        print("ANSWER:\n")

    return answer

# %% [markdown]
# ## 10. Test Cases

# %%
# Test 1: Single company
q1 = "What are the main products of Siemens Energy AG?"
a1 = rag_pipeline(q1)
print(a1)
# Out:
# ================================================================================
# Query: What are the main products of Siemens Energy AG?
#
# Expanded queries:
#   1. Provide a comprehensive, detailed listing of Siemens Energy AG's main product categories as presented by the company, enumerating the core hardware and equipment lines that constitute its primary product portfolio (for example, power generation equipment, power transmission and grid technology), and identify representative sub-products within each category along with any notable flagship offerings.
#   2. Describe Siemens Energy AG's main products from the vantage point of customer segments, distinguishing between products aimed at utility-scale power generation and those designed for industrial energy infrastructure projects, and specify the principal product offerings within each market segment.
#   3. Explain how Siemens Energy AG organizes and presents its main product lineup across technology families (for instance gas turbines, steam turbines, generators, transformers, and grid solutions), including the role of each family in the energy value chain and how these products integrate to deliver comprehensive energy infrastructure solutions.
#
# 🔍 'What are the main products of Siemens Energy AG?...' → Companies: ['Siemens Energy AG']
# 🔍 'Provide a comprehensive, detailed listing of Sieme...' → Companies: ['Siemens Energy AG']
# 🔍 'Describe Siemens Energy AG's main products from th...' → Companies: ['Siemens Energy AG']
# 🔍 'Explain how Siemens Energy AG organizes and presen...' → Companies: ['Siemens Energy AG']
# ✓ Retrieved 1 unique documents
#
# Context: 2988 chars from companies: {'Siemens Energy AG'}
#
# ================================================================================
# context: Company: Siemens Energy AG
# Description: Siemens Energy AG operates as an energy technology company worldwide. It operates in two segments, Gas and Power; and Siemens Gamesa Renewable Energy. The company provides gas and steam turbines, generators, gas engines, instrumentation and controls, and electrical systems, as well as performance enhancement, maintenance, customer training, and professional consulting services for central and distributed power generation; and transformers, air and gas-insulated switchgears, AC transmission systems, offshore windfarm grid connections, high voltage direct current transmission systems, high voltage substations, digital solutions and components, and other products. It also offers rotating equipment that includes industrial and aero-derivative gas turbines, turbo- and reciprocating compressors, power generation products, and compression trains and modules, as well as solutions in the fields of electrification, automation and digitization, plant safety, plant security, and water treatment. In addition, the company develops technologies in the fields of decarbonized energy and storage systems. Further, it offers onshore wind turbine design, engineering, manufacturing, and installation solutions for onshore markets; offshore wind turbine equipment design, manufacturing, and installation solutions; and operation and maintenance services for wind farms. The company serves utilities, independent power producers, project developers, oil and gas, transmission and distribution system operators, and industrial and infrastructure customers. Siemens Energy AG was founded in 1866 and is based in Munich, Germany.
# Industry: Energy Technology
# Related Industries: Power Generation, Renewable Energy, Oil and Gas, Energy Transmission and Distribution
# Products/Services: gas turbines, steam turbines, generators, transformers, switchgears, AC transmission systems, high voltage direct current transmission systems, high voltage substations, offshore windfarm grid connections, onshore wind turbines, offshore wind turbines, operation and maintenance services, performance enhancement services, maintenance services, customer training, professional consulting services, industrial gas turbines, aero-derivative gas turbines, turbo compressors, reciprocating compressors, power generation products, compression trains, compression modules, electrification solutions, automation solutions, digitization solutions, plant safety solutions, plant security solutions, water treatment solutions, decarbonized energy technologies, storage systems
# Keywords: energy technology, power generation, gas and power, renewable energy, wind energy, onshore wind, offshore wind, turbines, generators, transformers, electrical systems, transmission systems, distribution systems, high voltage, substations, grid connections, compressors, automation, digitization, decarbonization, energy storage, utilities, independent power producers, oil and gas, infrastructure
#
# question: What are the main products of Siemens Energy AG?
#
# ANSWER:
#
# - Gas turbines
# - Steam turbines
# - Generators
# - Transformers
# - Switchgears
# - AC transmission systems
# - High voltage direct current (HVDC) transmission systems
# - High voltage substations
# - Offshore windfarm grid connections
# - Onshore wind turbines
# - Offshore wind turbines
# - Operation and maintenance services
# - Performance enhancement services
# - Maintenance services
# - Customer training
# - Professional consulting services
# - Industrial gas turbines
# - Aero-derivative gas turbines
# - Turbo compressors
# - Reciprocating compressors
# - Power generation products
# - Compression trains
# - Compression modules
# - Electrification solutions
# - Automation solutions
# - Digitization solutions
# - Plant safety solutions
# - Plant security solutions
# - Water treatment solutions
# - Decarbonized energy technologies
# - Storage systems

# %%
# Test 2: Multi-company comparison
q2 = "Compare Traton SE and Deutsche Lufthansa AG"
a2 = rag_pipeline(q2)
print(a2)
# Out:
# ================================================================================
# Query: Compare Traton SE and Deutsche Lufthansa AG
#
# Expanded queries:
#   1. Provide a comprehensive side-by-side financial comparison of Traton SE and Deutsche Lufthansa AG, detailing the latest full-year results and the most recent quarterly figures, including revenue, operating income (EBIT) and EBITDA, net income, gross and operating margins, segment contributions (Traton's trucks and industrial mobility divisions, including vehicle systems and services, vs Lufthansa's passenger transport, cargo, and related service segments), year-over-year deltas, and any notable one-off items or non-recurring adjustments that affect comparability.
#   2. Analyze and compare the business models, value chains, and competitive positioning of Traton SE and Deutsche Lufthansa AG, outlining their core products and services (commercial vehicles and fleet solutions for Traton; airline operations, network reach, and ancillary services for Lufthansa), primary customer bases, revenue streams and cost structures, geographic revenue exposure, and how market cyclicality and capital expenditure cycles influence profitability and strategic priorities.
#   3. Examine the corporate structure, governance frameworks, and regulatory environments surrounding Traton SE and Deutsche Lufthansa AG, including parent-subordinate relationships (e.g., Traton's status within the Volkswagen Group versus Lufthansa Group ownership/listing structure), board composition and governance practices, major strategic decisions and capital allocation priorities, and key regulatory considerations specific to the European transport and aviation sectors that impact risk profile and long-term planning.
#   4. Compare valuation and market performance indicators for Traton SE and Deutsche Lufthansa AG, focusing on comparative stock price trends, market capitalization, liquidity, and valuation multiples (price-to-earnings, enterprise value to EBITDA, price-to-book where applicable), dividend policy and yield considerations, and investor sentiment factors that influence how the two companies are perceived in European capital markets despite operating in different transport sectors.
#   5. Contrast the environmental, social, and governance (ESG) profiles and decarbonization strategies of Traton SE and Deutsche Lufthansa AG, including emissions intensity, fleet/vehicle efficiency initiatives, investments in alternative propulsion or sustainable aviation fuels, sustainability reporting frameworks, and regulatory drivers affecting each sector in Europe.
#
# 🔍 'Compare Traton SE and Deutsche Lufthansa AG...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# 🔍 'Provide a comprehensive side-by-side financial com...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# 🔍 'Analyze and compare the business models, value cha...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# 🔍 'Examine the corporate structure, governance framew...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# 🔍 'Compare valuation and market performance indicator...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# 🔍 'Contrast the environmental, social, and governance...' → Companies: ['Traton SE', 'Deutsche Lufthansa AG']
# ✓ Retrieved 2 unique documents
#
# Context: 2882 chars from companies: {'Traton SE', 'Deutsche Lufthansa AG'}
#
# ================================================================================
# context: Company: Traton SE
# Description: Traton SE manufactures commercial vehicles worldwide. It operates in Industrial Business and Financial Services segments. The company offers light and heavy-duty commercial vehicles, such as trucks and bus chassis; vans; construction vehicles; city buses; and intercity and travel coaches, as well as spare parts and services. It also provides a cloud-based platform for freight transportation under the RIO brand name. The company offers its products and services under the MAN, Scania, Navistar, and Volkswagen Caminhões e Ônibus brands. In addition, it provides a range of financial solutions, including dealer and customer finance, leasing, and insurance products. The company was founded in 2015 and is based in Munich, Germany. Traton SE is a subsidiary of Volkswagen Finance Luxemburg S.A.
# Industry: commercial vehicle manufacturing
# Related Industries: automotive, transportation equipment
# Products/Services: trucks, buses, vans, construction vehicles, spare parts, vehicle services, freight transportation platform, dealer finance, customer finance, leasing, insurance
# Keywords: MAN, Scania, Navistar, Volkswagen Caminhões e Ônibus, RIO, commercial vehicles, heavy-duty trucks, bus chassis, city buses, intercity coaches, travel coaches
#
# ---
#
# Company: Deutsche Lufthansa AG
# Description: Deutsche Lufthansa AG operates as an aviation company in Germany and internationally. The company's Network Airlines segment offers passenger services. Its Eurowings segment provides passenger services through a route network of more than 100 destinations in over 50 countries. The company's Logistics Business segment offers transport services for various cargoes, including general cargo, dangerous goods, valuables, vulnerable, perishables, live animals, courier, emergency, airmail/e-commerce, and temperature sensitive goods services approximately 300 destinations in 100 countries. Its Maintenance, Repair and Overhaul Services (MRO) segment provides maintenance, repair, and overhaul services for civilian commercial aircraft serving original equipment manufacturers and aircraft leasing companies, operators of VIP jets, and airlines. The company's Catering Business segment engages in-flight services and convenience retail, as well as other areas, such as retail and food producers. As of December 31, 2021, it had a fleet of 713 aircraft. Deutsche Lufthansa AG was founded in 1926 and is headquartered in Cologne, Germany.
# Industry: Aviation
# Related Industries: Airlines, Aerospace, Transportation
# Products/Services: Passenger services, Cargo transport services, Maintenance, repair and overhaul services, In-flight catering services, Aircraft fleet operations
# Keywords: Lufthansa, German airline, International flights, Aircraft maintenance, Air cargo logistics, Eurowings, Aviation services, Fleet management, MRO services, In-flight services
#
# question: Compare Traton SE and Deutsche Lufthansa AG
#
# ANSWER:
#
# - Core business
#   - Traton SE: manufactures commercial vehicles worldwide; also offers a cloud freight platform (RIO) and financial solutions.
#   - Deutsche Lufthansa AG: operates as an aviation company with networks of passenger and cargo services, plus MRO and in-flight catering.
#
# - Industry
#   - Traton SE: commercial vehicle manufacturing (related to automotive/transportation equipment).
#   - Deutsche Lufthansa AG: Aviation (related to Airlines, Aerospace, Transportation).
#
# - Main products/services
#   - Traton SE: trucks, buses, vans, construction vehicles, spare parts, vehicle services; RIO platform; dealer/customer finance, leasing, insurance; brands MAN, Scania, Navistar, Volkswagen Caminhões e Ônibus.
#   - Deutsche Lufthansa AG: passenger services (Network Airlines, Eurowings); cargo transport; MRO; in-flight catering and retail.
#
# - Segments/brands
#   - Traton SE: brands MAN, Scania, Navistar, VW Caminhões e Ônibus; founded 2015; subsidiary of Volkswagen Finance Luxemburg S.A.
#   - Deutsche Lufthansa AG: segments include Network Airlines and Eurowings (passenger), Logistics (cargo), MRO, Catering; Eurowings brand; fleet context: 713 aircraft (as of 2021).
#
# - Geography/Headquarters
#   - Traton SE: based in Munich, Germany.
#   - Deutsche Lufthansa AG: headquartered in Cologne, Germany.
#
# - History
#   - Traton SE: founded in 2015.
#   - Deutsche Lufthansa AG: founded in 1926.

# %%
# Test 3: Broad query
q3 = "Which company is involved in both energy and transportation sec?"
a3 = rag_pipeline(q3)
print(a3)

# %% [markdown]
# ## 11. Interactive Interface

# %%
def ask(question: str):
    """Simple Q&A interface"""
    answer = rag_pipeline(question, verbose=False)
    print(f"\nQ: {question}")
    print(f"A: {answer}\n")

# Usage: ask("Your question here")

# %%
ask("Which company is involved in both energy and transportation sectors?")

# %% [markdown]
# ## System Architecture
#
# ```
# User Query → Query Expansion (3x) → Company Detection
#                                           ↓
#                     ┌─────────────────────┴─────────────────────┐
#                     ↓                                             ↓
#             Companies Found                              No Companies
#                     ↓                                             ↓
#         Filtered Retrieval (metadata)                  Broad Retrieval
#                     └─────────────────────┬─────────────────────┘
#                                           ↓
#                               Deduplicate Documents
#                                           ↓
#                               Aggregate Context
#                                           ↓
#                            Generate Answer (context-only)
# ```

# %% [markdown]
# # Evaluation Pipeline

# %% [markdown]
# In this section, we construct a test pipeline that uses an LLM to compare the response generated by the RAG system with the ground-truth answer.

# %% [markdown]
# Let's tune the Evaluator llm

# %%
# Initialize LLM Judge
judge_llm = llm

# judge_llm = ChatOpenAI(
#     model=LLM_MODEL, # For changing the model refer to the Config section
#     temperature=0,
#     openai_api_base="https://openrouter.ai/api/v1",
#     openai_api_key= Open_Router_API_Key,
# )

# Create Judge Prompt
judge_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are an evaluation judge. Compare the expected answer with the predicted answer.\n"
        "Determine if the predicted answer is correct (captures the same meaning/information).\n\n"
        "Format your response as:\n"
        "Decision: True/False\n"
        "Reason: [One short sentence explaining why]"
    ),
    (
        "human",
        "Question: {question}\n\n"
        "Expected Answer: {expected}\n\n"
        "Predicted Answer: {predicted}\n\n"
        "Evaluate if the predicted answer is correct:"
    )
])

# Create Judge Chain
judge_chain = judge_prompt | judge_llm | StrOutputParser()

# %% [markdown]
# In this step, we define a function to evaluate the accuracy of the RAG system.
#
# The function begins by loading a test CSV file that contains two required fields: `question` and `expected_answer`. It then iterates over each row of the dataset, generates a response using the RAG system for the given question, and employs a judge LLM to compare the generated answer with the expected answer, returning a Boolean result (`True` or `False`) for each comparison.
#
# F

# %%
def evaluate_with_llm_judge(rag_function, test_csv_path: str) -> float:
    """
    Evaluate RAG system using LLM as judge.

    Args:
        rag_function: Your RAG pipeline function
        test_csv_path: Path to test CSV with 'question' and 'expected_answer' columns

    Returns:
        Accuracy (0 to 1)
    """
    # Load test data
    test_df = pd.read_csv(test_csv_path)

    results = []
    correct_count = 0
    total_count = len(test_df)

    print(f"Evaluating {total_count} test cases...\n")

    # Evaluate each test case
    for idx, row in test_df.iterrows():
        question = row['question']
        expected = row['expected_answer']

        # Get RAG prediction
        predicted = rag_function(question, verbose=False)

        # Get LLM judge verdict
        verdict = judge_chain.invoke({
            "question": question,
            "expected": expected,
            "predicted": predicted
        })

        # Parse verdict and reason
        lines = verdict.strip().split('\n')
        decision_line = lines[0] if len(lines) > 0 else ""
        reason_line = lines[1] if len(lines) > 1 else ""

        is_correct = "true" in decision_line.lower()
        reason = reason_line.replace("Reason:", "").strip()

        results.append({
            'question': question,
            'expected_answer': expected,
            'rag_answer': predicted,
            'decision': is_correct,
            'reason': reason
        })

        if is_correct:
            correct_count += 1

        # Print progress
        status = "✓" if is_correct else "✗"
        print(f"{status} [{idx+1}/{total_count}] {question[:50]}...")
        print(f"   Reason: {reason}\n")

    # Calculate accuracy
    accuracy = correct_count / total_count

    # Print summary
    print("\n" + "="*80)
    print("EVALUATION RESULTS")
    print("="*80)
    print(f"Total Tests:     {total_count}")
    print(f"Correct:         {correct_count}")
    print(f"Incorrect:       {total_count - correct_count}")
    print(f"Accuracy:        {accuracy:.1%}")
    print("="*80 + "\n")

    # Save detailed results
    results_df = pd.DataFrame(results)
    results_df.to_csv('llm_judge_results.csv', index=False)
    print("✓ Detailed results saved to 'llm_judge_results.csv'")
    print("  Columns: question | expected_answer | rag_answer | decision | reason\n")

    return accuracy

# %%
accuracy = evaluate_with_llm_judge(
    rag_function=rag_pipeline,
    test_csv_path='/content/references.csv'
)

print(f"Final Accuracy: {accuracy:.1%}")
# Out:
# Evaluating 10 test cases...
#
# 🔍 'What does Traton SE specialize in?...' → Companies: ['Traton SE']
# 🔍 'Provide a comprehensive explanation of the core bu...' → Companies: ['Traton SE']
# 🔍 'Describe the brand architecture of Traton SE, incl...' → Companies: ['Traton SE']
# 🔍 'Explain the corporate structure and ownership cont...' → Companies: ['Traton SE']
# 🔍 'Identify Traton SE's geographic and production foo...' → Companies: ['Traton SE']
# 🔍 'Outline the target customer segments and market po...' → Companies: ['Traton SE']
# ✓ Retrieved 1 unique documents
#
# ✓ [1/10] What does Traton SE specialize in?...
#    Reason: The predicted answer preserves the core: TRATON SE manufactures commercial vehicles worldwide, and it also provides accurate extra details (spare parts/services, RIO platform, financial services, and brand lineup).
#
# 🔍 'Which company operates in the aviation industry?...' → Broad search
# 🔍 'Which company operates in the aviation industry, c...' → Broad search
# 🔍 'Within the aviation industry, identify a company t...' → Broad search
# 🔍 'Within the aviation industry, identify a company t...' → Companies: ['Lilium N.V.']
# 🔍 'Within the aviation industry, identify a company t...' → Broad search
# 🔍 'Within the aviation industry, identify a company t...' → Broad search
# ✓ Retrieved 9 unique documents
#
# ✓ [2/10] Which company operates in the aviation industry?...
#    Reason: It correctly identifies Deutsche Lufthansa AG as operating in aviation, and the additional Lilium N.V. mention is also an aviation company, not contradictory.
#
# 🔍 'What type of products does 2G Energy AG produce?...' → Companies: ['2G Energy AG']
# 🔍 'Provide a comprehensive breakdown of the product c...' → Companies: ['2G Energy AG']
# 🔍 'Describe the core technology platforms and product...' → Companies: ['2G Energy AG']
# 🔍 'Identify the primary end-use applications and inst...' → Companies: ['2G Energy AG']
# 🔍 'Outline the typical scalability options, size rang...' → Companies: ['2G Energy AG']
# 🔍 'Explain the organizational structure of 2G Energy ...' → Companies: ['2G Energy AG']
# ✓ Retrieved 1 unique documents
#
# ✓ [3/10] What type of products does 2G Energy AG produce?...
#    Reason: It correctly states that 2G Energy AG produces combined heat and power (CHP) systems, with the rest being additional details.
#
# 🔍 'Name a company that is involved in energy technolo...' → Broad search
# 🔍 'Provide the name of a company that is actively inv...' → Broad search
# 🔍 'Identify a company involved in energy technology s...' → Broad search
# 🔍 'Name a company engaged in energy technology soluti...' → Broad search
# 🔍 'Name a company in the energy technology solutions ...' → Broad search
# 🔍 'Identify a company involved in energy technology s...' → Broad search
# ✓ Retrieved 7 unique documents
#
# ✓ [4/10] Name a company that is involved in energy technolo...
#    Reason: The predicted answer correctly names Siemens Energy AG as a company involved in energy technology solutions.
#
# 🔍 'Which company is involved in the manufacturing of ...' → Broad search
# 🔍 'Provide the name(s) of the company or companies th...' → Broad search
# 🔍 'Determine whether the identified company or compan...' → Broad search
# 🔍 'List the full spectrum of engine products produced...' → Broad search
# 🔍 'Provide an assessment of market positioning among ...' → Broad search
# 🔍 'Describe the geographic footprint of each engine m...' → Broad search
# ✓ Retrieved 9 unique documents
#
# ✓ [5/10] Which company is involved in the manufacturing of ...
#    Reason: It correctly identifies MTU Aero Engines AG and states that it manufactures aircraft engines (with additional accurate details).
#
# 🔍 'What sector does Deutsche Lufthansa AG operate in?...' → Companies: ['Deutsche Lufthansa AG']
# 🔍 'Identify the primary sector and industry category ...' → Companies: ['Deutsche Lufthansa AG']
# 🔍 'Provide a formal taxonomy-based determination of w...' → Companies: ['Deutsche Lufthansa AG']
# 🔍 'In the context of corporate group classification, ...' → Companies: ['Deutsche Lufthansa AG']
# 🔍 'Describe how Deutsche Lufthansa AG is positioned w...' → Companies: ['Deutsche Lufthansa AG']
# ✓ Retrieved 1 unique documents
#
# ✓ [6/10] What sector does Deutsche Lufthansa AG operate in?...
#    Reason: The predicted answer identifies the same sector (aviation) using a synonymous term (industry).
#
# 🔍 'Identify a company that produces commercial vehicl...' → Broad search
# 🔍 'Identify a company that designs, engineers, and ma...' → Broad search
# 🔍 'Identify a company within the commercial vehicle m...' → Broad search
# 🔍 'Identify a company in the commercial vehicle produ...' → Broad search
# 🔍 'Identify a company that produces commercial vehicl...' → Broad search
# 🔍 'Identify a company active in the commercial vehicl...' → Broad search
# ✓ Retrieved 6 unique documents
#
# ✓ [7/10] Identify a company that produces commercial vehicl...
#    Reason: Identifies Traton SE as a company that produces commercial vehicles, matching the expected answer.
#
# 🔍 'What does Siemens Energy AG specialize in?...' → Companies: ['Siemens Energy AG']
# 🔍 'Provide an in-depth, detailed overview of the prim...' → Companies: ['Siemens Energy AG']
# 🔍 'Outline the service-oriented and project execution...' → Companies: ['Siemens Energy AG']
# 🔍 'Describe the typical market segments and applicati...' → Companies: ['Siemens Energy AG']
# 🔍 'Explain the core technology and innovation focus t...' → Companies: ['Siemens Energy AG']
# ✓ Retrieved 1 unique documents
#
# ✓ [8/10] What does Siemens Energy AG specialize in?...
#    Reason: It describes Siemens Energy as focused on energy technology and related equipment/services, which matches the core specialization in energy technology solutions.
#
# 🔍 'Which company is involved in both energy and trans...' → Broad search
# 🔍 'Identify all companies that have explicit, verifia...' → Broad search
# 🔍 'From the set of dual-sector companies identified, ...' → Broad search
# 🔍 'For each identified company, assemble an evidence-...' → Broad search
# 🔍 'Provide a geographic analysis of these dual-sector...' → Broad search
# ✓ Retrieved 10 unique documents
#
# ✗ [9/10] Which company is involved in both energy and trans...
#    Reason: The expected answer lists two separate companies (Traton SE for transportation and Siemens Energy AG for energy); BayWa is not identified as the company involved in both sectors.
#
# 🔍 'What industry does MTU Aero Engines AG operate in?...' → Companies: ['MTU Aero Engines AG']
# 🔍 'Please identify the primary industry classificatio...' → Companies: ['MTU Aero Engines AG']
# 🔍 'Within the context of the aerospace industry, desc...' → Companies: ['MTU Aero Engines AG']
# 🔍 'According to standard industry taxonomies (for exa...' → Companies: ['MTU Aero Engines AG']
# 🔍 'Does MTU Aero Engines AG's industry classification...' → Companies: ['MTU Aero Engines AG']
# 🔍 'Explain MTU Aero Engines AG's positioning within t...' → Companies: ['MTU Aero Engines AG']
# ✓ Retrieved 1 unique documents
#
# ✗ [10/10] What industry does MTU Aero Engines AG operate in?...
#    Reason: It adds "Defense" to the industry, whereas the expected answer specifies only "aerospace industry."
#
#
# ================================================================================
# EVALUATION RESULTS
# ================================================================================
# Total Tests:     10
# Correct:         8
# Incorrect:       2
# Accuracy:        80.0%
# ================================================================================
#
# ✓ Detailed results saved to 'llm_judge_results.csv'
#   Columns: question | expected_answer | rag_answer | decision | reason
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3624585677.py in <cell line: 0>()
# ----> 1 accuracy, results_df = evaluate_with_llm_judge(
#       2     rag_function=rag_pipeline,
#       3     test_csv_path='/content/references.csv'
#       4 )
#       5
#
# TypeError: cannot unpack non-iterable float object

# %%
results_df = pd.read_csv('llm_judge_results.csv')
results_df.head()
# Out:
#                                             question  \
# 0                 What does Traton SE specialize in?
# 1   Which company operates in the aviation industry?
# 2   What type of products does 2G Energy AG produce?
# 3  Name a company that is involved in energy tech...
# 4  Which company is involved in the manufacturing...
#
#                                      expected_answer  \
# 0  Traton SE manufactures commercial vehicles wor...
# 1  Deutsche Lufthansa AG operates in the aviation...
# 2  2G Energy AG produces combined heat and power ...
# 3  Siemens Energy AG is involved in energy techno...
# 4  MTU Aero Engines AG manufactures aircraft engi...
#
#                                           rag_answer  decision  \
# 0  Traton SE specializes in manufacturing commerc...      True
# 1  - Deutsche Lufthansa AG: Described as an aviat...      True
# 2  2G Energy AG produces combined heat and power ...      True
# 3  Siemens Energy AG. It is described as an energ...      True
# 4  MTU Aero Engines AG. It develops, manufactures...      True
#
#                                               reason
# 0  The predicted answer preserves the core: TRATO...
# 1  It correctly identifies Deutsche Lufthansa AG ...
# 2  It correctly states that 2G Energy AG produces...
# 3  The predicted answer correctly names Siemens E...
# 4  It correctly identifies MTU Aero Engines AG an...
